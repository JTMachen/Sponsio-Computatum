# %%
from Website import final_project
final_project.user_interface()
# Out:
# Logging out of your account. Thank you for visiting Sponsio Cpmoutatum.
# Are you a new or returning user? exit
# Thank you for visiting Sponsio Computatum.
